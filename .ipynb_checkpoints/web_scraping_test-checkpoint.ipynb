# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the CNN page you want to scrape
url = "https://edition.cnn.com/world/cnn-climate"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using Beautiful Soup
    soup = BeautifulSoup(response.text, "html.parser")

    # Find and extract article titles and dates
    articles = soup.find_all("div", class_="card")
    
    # Initialize lists to store titles and dates
    article_titles = []
    article_dates = []

    # Loop through the articles and extract titles and dates
    for article in articles:
        title = article.find("h3", class_="card__headline")
        date = article.find("span", class_="card__timestamp")
        
        if title and date:
            article_titles.append(title.text.strip())
            article_dates.append(date.text.strip())

    # Print the extracted titles and dates
    for i in range(len(article_titles)):
        print(f"Title: {article_titles[i]}")
        print(f"Date: {article_dates[i]}")
        print()

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

# %%
article_titles
# Out:
# []

# %%
article_dates
# Out:
# []

# %%
? soup.find_all
# Out:
# Signature:
#  soup.find_all(
#     name=None,
#     attrs={},
#     recursive=True,
#     string=None,
#     limit=None,
#     **kwargs,
# )
# Docstring:
# Look in the children of this PageElement and find all
# PageElements that match the given criteria.
#
# All find_* methods take a common set of arguments. See the online
# documentation for detailed explanations.
#
# :param name: A filter on tag name.
# :param attrs: A dictionary of filters on attribute values.
# :param recursive: If this is True, find_all() will perform a
#     recursive search of this PageElement's children. Otherwise,
#     only the direct children will be considered.
# :param limit: Stop looking after finding this many results.
# :kwargs: A dictionary of filters on attribute values.
# :return: A ResultSet of PageElements.
# :rtype: bs4.element.ResultSet
# File:      ~/anaconda3/envs/wid_datathon_2023/lib/python3.9/site-packages/bs4/element.py
# Type:      method

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the CNN page you want to scrape
url = "https://edition.cnn.com/world"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using Beautiful Soup
    soup = BeautifulSoup(response.text, "html.parser")

    # Find and extract article titles and dates
    articles = soup.find_all("div", class_="card")
    print(articles)

    # Initialize lists to store titles and dates
    article_titles = []
    article_dates = []

    # Loop through the articles and extract titles and dates
    for article in articles:
        title = article.find("div", class_="card__headline")
        date = article.find("time", class_="card__timestamp")
        
        if title and date:
            article_titles.append(title.text.strip())
            article_dates.append(date["datetime"])

    # Print the extracted titles and dates
    for i in range(len(article_titles)):
        print(f"Title: {article_titles[i]}")
        print(f"Date: {article_dates[i]}")
        print()

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# [<div class="card container__item container__item--type-section container_lead-plus-headlines__item container_lead-plus-headlines__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/2023/09/27/europe/nagorno-karabakh-exodus-armenia-explainer-intl/index.html" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/cl9wr1bie002q3d6el7pq8e4n_fill_1@published" data-word-count="1265">
# <a class="container__link container_lead-plus-headlines__link" data-link-type="article" href="/2023/09/27/europe/nagorno-karabakh-exodus-armenia-explainer-intl/index.html">
# <div class="container__item-media-wrapper container_lead-plus-headlines__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_lead-plus-headlines__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="05 Nagorno Karabakh refugees 092623" data-observe-resizes="" data-original-height="2000" data-original-ratio="0.6666666666666666" data-original-width="3000" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_cl9wr1bie002q3d6el7pq8e4n_fill_1@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230927110444-05-nagorno-karabakh-refugees-092623.jpg?c=original">
# <script>function imageLoadError(img) {
#     const fallbackImage = '/media/sites/cnn/cnn-fallback-image.jpg';
#
#     img.removeAttribute('onerror');
#     img.src = fallbackImage;
#     let element = img.previousElementSibling;
#
#     while (element && element.tagName === 'SOURCE') {
#       element.srcset = fallbackImage;
#       element = element.previousElementSibling;
#     }
#   }</script>
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="438" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230
index.html">
# <div class="container__text container_lead-plus-headlines__text">
# <div class="container__headline container_lead-plus-headlines__headline">
# <span data-editable="headline">Breanna Stewart named WNBA MVP for a second time</span>
# </div>
# </div>
# </a>
# </div>, <div class="card container__item container__item--type-section container_lead-plus-headlines__item container_lead-plus-headlines__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/2023/09/22/us/illinois-cancer-treatment-wish-delivery-cnnheroes/index.html" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clb55iiiv003e3b6en84mjvyk_fill_1@published" data-word-count="943">
# <a class="container__link container_lead-plus-headlines__link" data-link-type="article" href="/2023/09/22/us/illinois-cancer-treatment-wish-delivery-cnnheroes/index.html">
# <div class="container__item-media-wrapper container_lead-plus-headlines__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_lead-plus-headlines__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="kelli ritschel boehle lamp cnnheroes" data-observe-resizes="" data-original-height="1080" data-original-ratio="0.5625" data-original-width="1920" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clb55iiiv003e3b6en84mjvyk_fill_1@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230920122720-kelli-ritschel-boehle-lamp-cnnheroes.jpg?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="438" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230920122720-kelli-ritschel-boehle-lamp-cnnheroes.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="438" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230920122720-kelli-ritschel-boehle-lamp-cnnheroes.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="270" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230920122720-kelli-ritschel-boehle-lamp-cnnheroes.jpg?c=16x9&amp;q=h_270,w_480,c_fill" width="480"/><img alt="kelli ritschel boehle lamp cnnheroes" class="image__dam-img image__dam-img--loading" height="1080" loading="lazy" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/230920122720-kelli-ritschel-boehle-lamp-cnnheroes.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="1920"/></picture>
# </div>
# <div class="image__metadata"></div>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_lead-plus-headlines__link" data-link-type="article" href="/2023/09/22/us/illinois-cancer-treatment-wish-delivery-cnnheroes/index.html">
# <div class="container__text container_lead-plus-headlines__text">
# <div class="container__headline container_lead-plus-headlines__headline">
# <span data-editable="headline">The Wish Maker: She makes dreams come true for hundreds of young adults battling cancer</span>
# </div>
# </div>
# </a>
# </div>, <div class="card container__item container__item--type-section container_lead-plus-headlines__item container_lead-plus-headlines__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/2023/08/31/us/new-york-women-prison-support-cnnheroes/index.html" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clb55iiiv003e3b6en84mjvyk_fill_2@published" data-word-count="943">
# <a class="container__link container_lead-plus-headlines__link" data-link-type="article" href="/2023/08/31/us/new-york-women-prison-support-cnnheroes/index.html">
# <div class="container__text container_lead-plus-headlines__text">
# <div class="container__headline container_lead-plus-headlines__headline">
# <span data-editable="headline">Some 60,000 people return from prison each year. Her program is now a nationwide model for providing second chances</span>
# </div>
# </div>
# </a>
# </div>, <div class="card container__item container__item--type-section container_lead-plus-headlines__item container_lead-plus-headlines__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/2023/08/18/us/montana-cancer-native-american-reservation-food-insecurity-cnnheroes/index.html" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clb55iiiv003e3b6en84mjvyk_fill_3@published">
# <a class="container__link container_lead-plus-headlines__link" data-link-type="article" href="/2023/08/18/us/montana-cancer-native-american-reservation-food-insecurity-cnnheroes/index.html">
# <div class="container__text container_lead-plus-headlines__text">
# <div class="container__headline container_lead-plus-headlines__headline">
# <span data-editable="headline">This CNN Hero’s battle with cancer inspired her lifesaving work helping families in her Native American community</span>
# </div>
# </div>
# </a>
# </div>, <div class="card container__item container__item--type-section container_lead-plus-headlines__item container_lead-plus-headlines__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/2023/08/11/world/ghana-van-mental-health-medical-care-cnnheroes/index.html" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clb55iiiv003e3b6en84mjvyk_fill_4@published">
# <a class="container__link container_lead-plus-headlines__link" data-link-type="article" href="/2023/08/11/world/ghana-van-mental-health-medical-care-cnnheroes/index.html">
# <div class="container__text container_lead-plus-headlines__text">
# <div class="container__headline container_lead-plus-headlines__headline">
# <span data-editable="headline">He converted a van into a mobile medical clinic. Now, he’s bringing care to thousands in rural Ghana</span>
# </div>
# </div>
# </a>
# </div>]
