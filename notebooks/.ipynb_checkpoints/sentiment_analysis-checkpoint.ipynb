# %% [markdown]
# # Import sample data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pycountry
import re

# Function to get the various attributes of the article
def getArticles(articles):
    all_articles = []
    for article in articles:
        article_title = article.find('title').text
        article_link = getattr(article.find('link'), 'text', None)
        article_desc = getattr(article.find('description'), 'text', None)
        article_published = getattr(article.find('pubDate'), 'text', None)
        all_articles.append({
            'title':article_title,
            'link':article_link,
            'description':article_desc,
            'published':article_published
        })
    return all_articles
    
# Function to invoke CNN Scrapper
def cnn_news_scrapper(URL):
    try:
        r = requests.get(URL)
        soupContent = BeautifulSoup(r.content,'xml')
        print('Job Succeeded returning Status Code: ', r.status_code)
        items = soupContent.findAll('item')
        print('Total News Content')
        print(len(items))
        print(items)
        return getArticles(soupContent.findAll('item'))
    except Exception as e:
        print('Scraping failed due to the below exception')
        print(e)

data = cnn_news_scrapper('https://feeds.bbci.co.uk/news/science_and_environment/rss.xml?edition=uk')

df = pd.DataFrame(data)
# Out:
# Job Succeeded returning Status Code:  200
# Total News Content
# 19
# [<item>
# <title>Alien life in Universe: Scientists say finding it is 'only a matter of time'</title>
# <description>Experts are optimistic of detecting life signs on a faraway world within our lifetimes - possibly in the next few years.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66950930?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66950930</guid>
# <pubDate>Fri, 29 Sep 2023 23:20:01 GMT</pubDate>
# </item>, <item>
# <title>UK unready as wildfires surge, warns firefighters' union</title>
# <description>Wildfire response across the UK is an under-resourced "postcode lottery", claims a new union report.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66948836?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66948836</guid>
# <pubDate>Fri, 29 Sep 2023 01:22:34 GMT</pubDate>
# </item>, <item>
# <title>Single-use plastic ban: Some firms unaware of England's new ban</title>
# <description>Plastic cutlery is banned in England from Sunday but plastic containers for takeaway meals are not.</description>
# <link>https://www.bbc.co.uk/news/business-66946643?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/business-66946643</guid>
# <pubDate>Fri, 29 Sep 2023 10:57:49 GMT</pubDate>
# </item>, <item>
# <title>Nature crisis: One in six species at risk of extinction in Great Britain</title>
# <description>The loss of Britain's wildlife is outpacing efforts to conserve and protect nature, a major report reveals.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66923930?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66923930</guid>
# <pubDate>Wed, 27 Sep 2023 18:07:20 GMT</pubDate>
# </item>, <item>
# <title>Scientists get closer to solving mystery of antimatter</title>
# <description>The elusive substance holds the key to discovering how the Universe was formed.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66890649?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66890649</guid>
# <pubDate>Wed, 27 Sep 2023 15:06:19 GMT</pubDate>
# </item>, <item>
# <title>Government to delay new environmental building rules</title>
# <description>Environmentalists say delaying the implementation of new biodiversity rules is "a hammer blow for nature".</description>
# <link>https://www.bbc.co.uk/news/science-environment-66927242?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66927242</guid>
# <pubDate>Tue, 26 Sep 2023 23:00:49 GMT</pubDate>
# </item>, <item>
# <title>Climate change: Six young people take 32 countries to court</title>
# <description>They claim governments' slow action on climate change violates their human rights.</description>
# <link>https://www.bbc.co.uk/news/world-europe-66923590?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/world-europe-66923590</guid>
# <pubDate>Wed, 27 Sep 2023 00:53:18 GMT</pubDate>
# </item>, <item>
# <title>Water firms forced to pay back customers for poor performance</title>
# <description>Regulator Ofwat orders companies in England and Wales to cut bills after missing targets.</description>
# <link>https://www.bbc.co.uk/news/business-66922070?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/business-66922070</guid>
# <pubDate>Tue, 26 Sep 2023 11:51:13 GMT</pubDate>
# </item>, <item>
# <title>Richest oil states should pay climate tax, says Gordon Brown</title>
# <description>The former Labour PM wants the wealthiest oil producers to help poorer nations tackle climate change.</description>
# <link>https://www.bbc.co.uk/news/uk-politics-66906395?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/uk-politics-66906395</guid>
# <pubDate>Mon, 25 Sep 2023 05:00:05 GMT</pubDate>
# </item>, <item>
# <title>Africa proposes global carbon taxes to fight climate change</title>
# <description>Despite suffering some of the worst impacts of climate change, the continent only gets 12% of financing.</description>
# <link>https://www.bbc.co.uk/news/world-africa-66733557?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/world-africa-66733557</guid>
# <pubDate>Thu, 07 Sep 2023 07:39:58 GMT</pubDate>
# </item>, <item>
# <title>Kenya's Lake Baringo: Surviving hippo and crocodile attacks</title>
# <description>Residents say that with Lake Baringo getting bigger they are at greater risk of attack.</description>
# <link>https://www.bbc.co.uk/news/world-africa-66707507?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/world-africa-66707507</guid>
# <pubDate>Wed, 06 Sep 2023 00:58:05 GMT</pubDate>
# </item>, <item>
# <title>Ocean heat record broken, with grim implications for the planet</title>
# <description>The oceans are a vital regulator for the climate and our weather but are rapidly heating up.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66387537?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66387537</guid>
# <pubDate>Fri, 04 Aug 2023 04:00:03 GMT</pubDate>
# </item>, <item>
# <title>Will the Gulf Stream really collapse by 2025?</title>
# <description>A new paper says its collapse could be imminent, but some experts argue science is not established.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66289494?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66289494</guid>
# <pubDate>Wed, 26 Jul 2023 14:13:07 GMT</pubDate>
# </item>, <item>
# <title>What is net zero and how are the UK and other countries doing?</title>
# <description>The UK may weaken some key green commitments, despite its pledge to reach "net zero" by 2050.</description>
# <link>https://www.bbc.co.uk/news/science-environment-58874518?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-58874518</guid>
# <pubDate>Wed, 20 Sep 2023 21:15:05 GMT</pubDate>
# </item>, <item>
# <title>Osiris-Rex: Nasa confirms return of asteroid Bennu samples</title>
# <description>A capsule carrying debris from asteroid Bennu lands safely in the Utah desert.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66893661?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66893661</guid>
# <pubDate>Mon, 25 Sep 2023 02:27:12 GMT</pubDate>
# </item>, <item>
# <title>Tantalising sign of possible life on faraway world</title>
# <description>Nasa's James Webb Telescope may have discovered a molecule thought only to be produced by life.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66786611?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66786611</guid>
# <pubDate>Tue, 12 Sep 2023 12:36:52 GMT</pubDate>
# </item>, <item>
# <title>James Webb: Telescope reveals new detail in famous supernova</title>
# <description>Looking like a pearl necklace, the object known as SN1987A is the closest star explosion to Earth.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66670705?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66670705</guid>
# <pubDate>Thu, 31 Aug 2023 14:02:55 GMT</pubDate>
# </item>, <item>
# <title>Aditya-L1: India successfully launches its first mission of the Sun</title>
# <description>Aditya-L1 will carry out scientific studies of the Sun from a vantage point 1.5 million km above Earth.</description>
# <link>https://www.bbc.co.uk/news/world-asia-india-66643805?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/world-asia-india-66643805</guid>
# <pubDate>Sat, 02 Sep 2023 07:43:13 GMT</pubDate>
# </item>, <item>
# <title>Chandrayaan-3: Isro puts India's Moon lander and rover in 'sleep mode'</title>
# <description>It is hoped the Vikram lander and Pragyaan rover will reawaken when the next lunar day starts.</description>
# <link>https://www.bbc.co.uk/news/world-asia-india-66704451?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/world-asia-india-66704451</guid>
# <pubDate>Mon, 04 Sep 2023 11:02:00 GMT</pubDate>
# </item>]

# %%
df.head()
# Out:
#                                                title  \
# 0  Alien life in Universe: Scientists say finding...
# 1  UK unready as wildfires surge, warns firefight...
# 2  Single-use plastic ban: Some firms unaware of ...
# 3  Nature crisis: One in six species at risk of e...
# 4  Scientists get closer to solving mystery of an...
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/science-environment...
# 1  https://www.bbc.co.uk/news/science-environment...
# 2  https://www.bbc.co.uk/news/business-66946643?a...
# 3  https://www.bbc.co.uk/news/science-environment...
# 4  https://www.bbc.co.uk/news/science-environment...
#
#                                          description  \
# 0  Experts are optimistic of detecting life signs...
# 1  Wildfire response across the UK is an under-re...
# 2  Plastic cutlery is banned in England from Sund...
# 3  The loss of Britain's wildlife is outpacing ef...
# 4  The elusive substance holds the key to discove...
#
#                        published
# 0  Fri, 29 Sep 2023 23:20:01 GMT
# 1  Fri, 29 Sep 2023 01:22:34 GMT
# 2  Fri, 29 Sep 2023 10:57:49 GMT
# 3  Wed, 27 Sep 2023 18:07:20 GMT
# 4  Wed, 27 Sep 2023 15:06:19 GMT

# %% [markdown]
# # Conduct sentiment analysis using SpaCY & VADER

# %%
import pandas as pd
from textblob import TextBlob
import spacy
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Load a SpaCy Model
nlp = spacy.load('en_core_web_sm')

# Initialize VADER SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Function to get sentiment
def get_sentiment(text):
    # Process text with SpaCy
    doc = nlp(text)
    
    # Convert SpaCy Doc to TextBlob object for sentiment analysis
    blob = TextBlob(doc.text)
    
    # Return the polarity
    return blob.sentiment.polarity

# Function to apply sentiment analysis
def get_vader_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    return sentiment_score['compound']  # return the compound score, or return the whole dictionary if needed.

# Apply the function to the text column and create a new column 'sentiment'
df['spacy_title'] = df['title'].apply(get_sentiment)
df['spacy_description'] = df['description'].apply(get_sentiment)
df['vader_title'] = df['title'].apply(get_vader_sentiment)
df['vader_description'] = df['description'].apply(get_vader_sentiment)

# %%
df.head(5)
# Out:
#                                                title  \
# 0  Alien life in Universe: Scientists say finding...
# 1  UK unready as wildfires surge, warns firefight...
# 2  Single-use plastic ban: Some firms unaware of ...
# 3  Nature crisis: One in six species at risk of e...
# 4  Scientists get closer to solving mystery of an...
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/science-environment...
# 1  https://www.bbc.co.uk/news/science-environment...
# 2  https://www.bbc.co.uk/news/business-66946643?a...
# 3  https://www.bbc.co.uk/news/science-environment...
# 4  https://www.bbc.co.uk/news/science-environment...
#
#                                          description  \
# 0  Experts are optimistic of detecting life signs...
# 1  Wildfire response across the UK is an under-re...
# 2  Plastic cutlery is banned in England from Sund...
# 3  The loss of Britain's wildlife is outpacing ef...
# 4  The elusive substance holds the key to discove...
#
#                        published  title_sentiment  description_sentiment  \
# 0  Fri, 29 Sep 2023 23:20:01 GMT        -0.125000              -0.066667
# 1  Fri, 29 Sep 2023 01:22:34 GMT         0.000000               0.136364
# 2  Fri, 29 Sep 2023 10:57:49 GMT         0.068182               0.000000
# 3  Wed, 27 Sep 2023 18:07:20 GMT         0.800000               0.062500
# 4  Wed, 27 Sep 2023 15:06:19 GMT         0.000000               0.000000
#
#    spacy_title  spacy_description  vader_title  vader_description
# 0    -0.125000          -0.066667       0.0258             0.3182
# 1     0.000000           0.136364      -0.1027             0.0000
# 2     0.068182           0.000000      -0.8402            -0.2500
# 3     0.800000           0.062500      -0.2732             0.0772
# 4     0.000000           0.000000       0.3400             0.0000

# %%
# When SpaCY & VADER algorithms differ, how do we want to deal with this?
