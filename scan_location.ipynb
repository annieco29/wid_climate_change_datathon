# %% [markdown]
# # Using sample RSS Beautiful Soup dataframe to test

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pycountry
import re

# %%
# Function to get the various attributes of the article
def getArticles(articles):
    all_articles = []
    for article in articles:
        article_title = article.find('title').text
        article_link = getattr(article.find('link'), 'text', None)
        article_desc = getattr(article.find('description'), 'text', None)
        article_published = getattr(article.find('pubDate'), 'text', None)
        all_articles.append({
            'title':article_title,
            'link':article_link,
            'description':article_desc,
            'published':article_published
        })
    return all_articles
    
# Function to invoke CNN Scrapper
def cnn_news_scrapper(URL):
    try:
        r = requests.get(URL)
        soupContent = BeautifulSoup(r.content,'xml')
        print('Job Succeeded returning Status Code: ', r.status_code)
        items = soupContent.findAll('item')
        print('Total News Content')
        print(len(items))
        print(items)
        return getArticles(soupContent.findAll('item'))
    except Exception as e:
        print('Scraping failed due to the below exception')
        print(e)

# %%
data = cnn_news_scrapper('https://feeds.bbci.co.uk/news/science_and_environment/rss.xml?edition=uk')
# Out:
# Job Succeeded returning Status Code:  200
# Total News Content
# 19
# [<item>
# <title>Alien life in Universe: Scientists say finding it is 'only a matter of time'</title>
# <description>Experts are optimistic of detecting life signs on a faraway world within our lifetimes - possibly in the next few years.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66950930?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66950930</guid>
# <pubDate>Fri, 29 Sep 2023 23:20:01 GMT</pubDate>
# </item>, <item>
# <title>UK unready as wildfires surge, warns firefighters' union</title>
# <description>Wildfire response across the UK is an under-resourced "postcode lottery", claims a new union report.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66948836?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66948836</guid>
# <pubDate>Fri, 29 Sep 2023 01:22:34 GMT</pubDate>
# </item>, <item>
# <title>Single-use plastic ban: Some firms unaware of England's new ban</title>
# <description>Plastic cutlery is banned in England from Sunday but plastic containers for takeaway meals are not.</description>
# <link>https://www.bbc.co.uk/news/business-66946643?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/business-66946643</guid>
# <pubDate>Fri, 29 Sep 2023 10:57:49 GMT</pubDate>
# </item>, <item>
# <title>Nature crisis: One in six species at risk of extinction in Great Britain</title>
# <description>The loss of Britain's wildlife is outpacing efforts to conserve and protect nature, a major report reveals.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66923930?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66923930</guid>
# <pubDate>Wed, 27 Sep 2023 18:07:20 GMT</pubDate>
# </item>, <item>
# <title>Scientists get closer to solving mystery of antimatter</title>
# <description>The elusive substance holds the key to discovering how the Universe was formed.</description>
# <link>https://www.bbc.co.uk/news/science-environment-66890649?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66890649</guid>
# <pubDate>Wed, 27 Sep 2023 15:06:19 GMT</pubDate>
# </item>, <item>
# <title>Government to delay new environmental building rules</title>
# <description>Environmentalists say delaying the implementation of new biodiversity rules is "a hammer blow for nature".</description>
# <link>https://www.bbc.co.uk/news/science-environment-66927242?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/science-environment-66927242</guid>
# <pubDate>Tue, 26 Sep 2023 23:00:49 GMT</pubDate>
# </item>, <item>
# <title>Climate change: Six young people take 32 countries to court</title>
# <description>They claim governments' slow action on climate change violates their human rights.</description>
# <link>https://www.bbc.co.uk/news/world-europe-66923590?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/world-europe-66923590</guid>
# <pubDate>Wed, 27 Sep 2023 00:53:18 GMT</pubDate>
# </item>, <item>
# <title>Water firms forced to pay back customers for poor performance</title>
# <description>Regulator Ofwat orders companies in England and Wales to cut bills after missing targets.</description>
# <link>https://www.bbc.co.uk/news/business-66922070?at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news
at_medium=RSS&amp;at_campaign=KARANGA</link>
# <guid isPermaLink="false">https://www.bbc.co.uk/news/world-asia-india-66704451</guid>
# <pubDate>Mon, 04 Sep 2023 11:02:00 GMT</pubDate>
# </item>]

# %%
df = pd.DataFrame(data)
df.head(1)
# Out:
#                                                title  \
# 0  Alien life in Universe: Scientists say finding...
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/science-environment...
#
#                                          description  \
# 0  Experts are optimistic of detecting life signs...
#
#                        published
# 0  Fri, 29 Sep 2023 23:20:01 GMT

# %% [markdown]
# # Method 1: Find location based on list of countries/states within the US

# %%
# Creating a list of dictionaries, where each dictionary contains information about a country.
countries_info = []
for country in pycountry.countries:
    countries_info.append({
        'country_name': country.name,
        'alpha_2': country.alpha_2,
        'alpha_3': country.alpha_3,
        'official_name': getattr(country, 'official_name', country.name)  # Some countries might not have an official_name attribute.
    })

# Creating a DataFrame from the list of dictionaries.
df_countries = pd.DataFrame(countries_info)

# %%
# Extracting US state information from pycountry.
states_info = [{'state_code': subdiv.code.split('-')[1], 'state_name': subdiv.name} for subdiv in pycountry.subdivisions.get(country_code='US')]

# Creating a DataFrame from the list of dictionaries.
df_states = pd.DataFrame(states_info)

# Display the first few rows of the DataFrame.
print(df_states.head())
# Out:
#   state_code      state_name
# 0         CO        Colorado
# 1         IA            Iowa
# 2         MD        Maryland
# 3         NC  North Carolina
# 4         OH            Ohio

# %%
# Creating a dictionary to hold each column as a separate list
countries_as_lists = {col_name: df_countries[col_name].tolist() for col_name in df_countries.columns}

# Creating a dictionary to hold each column as a separate list
states_as_lists = {col_name: df_states[col_name].tolist() for col_name in df_states.columns}

# %%
country_name = columns_as_lists['country_name']
country_code2 = columns_as_lists['alpha_2']
country_code3 = columns_as_lists['alpha_3']
state_name = states_as_lists['state_name']
state_code = states_as_lists['state_code']

# %% [markdown]
# ## If title/description matches any item in country/state list, create column identifying location that matches

# %%
pttrn = f"({'|'.join(country_name)})"
title_country = df['title'].str.extract(pttrn, flags=re.IGNORECASE, expand=False)
df['title_country'] = title_country[0]

pttrn = f"({'|'.join(state_name)})"
df['title_state'] = df['title'].str.extract(pttrn, flags=re.IGNORECASE, expand=False)

pttrn = f"({'|'.join(country_name)})"
descrip_country = df['description'].str.extract(pttrn, flags=re.IGNORECASE, expand=False)
df['descrip_country'] = descrip_country[0]

pttrn = f"({'|'.join(state_name)})"
df['descrip_state'] = df['description'].str.extract(pttrn, flags=re.IGNORECASE, expand=False)

# %%
df
# Out:
#                                                 title  \
# 0   Alien life in Universe: Scientists say finding...
# 1   UK unready as wildfires surge, warns firefight...
# 2   Single-use plastic ban: Some firms unaware of ...
# 3   Nature crisis: One in six species at risk of e...
# 4   Scientists get closer to solving mystery of an...
# 5   Government to delay new environmental building...
# 6   Climate change: Six young people take 32 count...
# 7   Water firms forced to pay back customers for p...
# 8   Richest oil states should pay climate tax, say...
# 9   Africa proposes global carbon taxes to fight c...
# 10  Kenya's Lake Baringo: Surviving hippo and croc...
# 11  Ocean heat record broken, with grim implicatio...
# 12      Will the Gulf Stream really collapse by 2025?
# 13  What is net zero and how are the UK and other ...
# 14  Osiris-Rex: Nasa confirms return of asteroid B...
# 15  Tantalising sign of possible life on faraway w...
# 16  James Webb: Telescope reveals new detail in fa...
# 17  Aditya-L1: India successfully launches its fir...
# 18  Chandrayaan-3: Isro puts India's Moon lander a...
#
#                                                  link  \
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14          Utah
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN

# %% [markdown]
# # Method 2: Use NLP to detect location

# %%
#Download English
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/thienthanhtrinh/.local/lib/python3.11/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/thienthanhtrinh/.local/lib/python3.11/site-packages (from spacy) (2.3.0)
# Requirement already satisfied: jinja2 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/thienthanhtrinh/.local/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/thienthanhtrinh/.local/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in /Users/thienthanhtrinh/.local/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.1)
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 8.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/thienthanhtrinh/.local/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/thienthanhtrinh/.local/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.3.0)
# Requirement already satisfied: jinja2 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/thienthanhtrinh/.local/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/thienthanhtrinh/.local/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in /Users/thienthanhtrinh/.local/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/thienthanhtrinh/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# Load the SpaCy model
nlp = spacy.load('en_core_web_sm')

# Extract location entities
#GPE = geopolitical entities (cities/countries)
#LOC = non-GPE, mountain ranges/bodies of water

def extract_locations(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ in ['GPE', 'LOC']]

# Apply the function to the 'Text' column and create a new column 'Locations' with the results
df['nlp_title'] = df['title'].apply(extract_locations)
df['nlp_descrip'] = df['description'].apply(extract_locations)

# Display the updated DataFrame
display(df)
# Out:
#                                                 title  \
# 0   Alien life in Universe: Scientists say finding...
# 1   UK unready as wildfires surge, warns firefight...
# 2   Single-use plastic ban: Some firms unaware of ...
# 3   Nature crisis: One in six species at risk of e...
# 4   Scientists get closer to solving mystery of an...
# 5   Government to delay new environmental building...
# 6   Climate change: Six young people take 32 count...
# 7   Water firms forced to pay back customers for p...
# 8   Richest oil states should pay climate tax, say...
# 9   Africa proposes global carbon taxes to fight c...
# 10  Kenya's Lake Baringo: Surviving hippo and croc...
# 11  Ocean heat record broken, with grim implicatio...
# 12      Will the Gulf Stream really collapse by 2025?
# 13  What is net zero and how are the UK and other ...
# 14  Osiris-Rex: Nasa confirms return of asteroid B...
# 15  Tantalising sign of possible life on faraway w...
# 16  James Webb: Telescope reveals new detail in fa...
# 17  Aditya-L1: India successfully launches its fir...
# 18  Chandrayaan-3: Isro puts India's Moon lander a...
#
#                                                  link  \
# 0   https://www.bbc.co.uk/news/science-environment...
# 1   https://www.bbc.co.uk/news/science-environment...
# 2   https://www.bbc.co.uk/news/business-66946643?a...
# 3   https://www.bbc.co.uk/news/science-environment...
# 4   https://www.bbc.co.uk/news/science-environment...
# 5   https://www.bbc.co.uk/news/science-environment...
# 6   https://www.bbc.co.uk/news/world-europe-669235...
# 7   https://www.bbc.co.uk/news/business-66922070?a...
# 8   https://www.bbc.co.uk/news/uk-politics-6690639...
# 9   https://www.bbc.co.uk/news/world-africa-667335...
# 10  https://www.bbc.co.uk/news/world-africa-667075...
# 11  https://www.bbc.co.uk/news/science-environment...
# 12  https://www.bbc.co.uk/news/science-environment...
# 13  https://www.bbc.co.uk/news/science-environment...
# 14  https://www.bbc.co.uk/news/science-environment...
# 15  https://www.bbc.co.uk/news/science-environment...
# 16  https://www.bbc.co.uk/news/science-environment...
# 17  https://www.bbc.co.uk/news/world-asia-india-66...
# 18  https://www.bbc.co.uk/news/world-asia-india-66...
#
#                                           description  \
# 0   Experts are optimistic of detecting life signs...
# 1   Wildfire response across the UK is an under-re...
# 2   Plastic cutlery is banned in England from Sund...
# 3   The loss of Britain's wildlife is outpacing ef...
# 4   The elusive substance holds the key to discove...
# 5   Environmentalists say delaying the implementat...
# 6   They claim governments' slow action on climate...
# 7   Regulator Ofwat orders companies in England an...
# 8   The former Labour PM wants the wealthiest oil ...
# 9   Despite suffering some of the worst impacts of...
# 10  Residents say that with Lake Baringo getting b...
# 11  The oceans are a vital regulator for the clima...
# 12  A new paper says its collapse could be imminen...
# 13  The UK may weaken some key green commitments, ...
# 14  A capsule carrying debris from asteroid Bennu ...
# 15  Nasa's James Webb Telescope may have discovere...
# 16  Looking like a pearl necklace, the object know...
# 17  Aditya-L1 will carry out scientific studies of...
# 18  It is hoped the Vikram lander and Pragyaan rov...
#
#                         published title_country title_state descrip_country  \
# 0   Fri, 29 Sep 2023 23:20:01 GMT           NaN         NaN             NaN
# 1   Fri, 29 Sep 2023 01:22:34 GMT           NaN         NaN             NaN
# 2   Fri, 29 Sep 2023 10:57:49 GMT           NaN         NaN             NaN
# 3   Wed, 27 Sep 2023 18:07:20 GMT           NaN         NaN             NaN
# 4   Wed, 27 Sep 2023 15:06:19 GMT           NaN         NaN             NaN
# 5   Tue, 26 Sep 2023 23:00:49 GMT           NaN         NaN             NaN
# 6   Wed, 27 Sep 2023 00:53:18 GMT           NaN         NaN             NaN
# 7   Tue, 26 Sep 2023 11:51:13 GMT           NaN         NaN             NaN
# 8   Mon, 25 Sep 2023 05:00:05 GMT           NaN         NaN             NaN
# 9   Thu, 07 Sep 2023 07:39:58 GMT           NaN         NaN             NaN
# 10  Wed, 06 Sep 2023 00:58:05 GMT         Kenya         NaN             NaN
# 11  Fri, 04 Aug 2023 04:00:03 GMT           NaN         NaN             NaN
# 12  Wed, 26 Jul 2023 14:13:07 GMT           NaN         NaN             NaN
# 13  Wed, 20 Sep 2023 21:15:05 GMT           NaN         NaN             NaN
# 14  Mon, 25 Sep 2023 02:27:12 GMT           NaN         NaN             NaN
# 15  Tue, 12 Sep 2023 12:36:52 GMT           NaN         NaN             NaN
# 16  Thu, 31 Aug 2023 14:02:55 GMT           NaN         NaN             NaN
# 17  Sat, 02 Sep 2023 07:43:13 GMT         India         NaN             NaN
# 18  Mon, 04 Sep 2023 11:02:00 GMT         India         NaN             NaN
#
#    descrip_state        Locations        nlp_title       nlp_descrip
# 0            NaN               []               []                []
# 1            NaN             [UK]             [UK]              [UK]
# 2            NaN        [England]        [England]         [England]
# 3            NaN  [Great Britain]  [Great Britain]         [Britain]
# 4            NaN               []               []                []
# 5            NaN               []               []                []
# 6            NaN               []               []                []
# 7            NaN               []               []  [England, Wales]
# 8            NaN               []               []                []
# 9            NaN         [Africa]         [Africa]                []
# 10           NaN          [Kenya]          [Kenya]                []
# 11           NaN               []               []                []
# 12           NaN               []               []                []
# 13           NaN             [UK]             [UK]              [UK]
# 14          Utah               []               []            [Utah]
# 15           NaN               []               []                []
# 16           NaN               []               []  [SN1987A, Earth]
# 17           NaN     [India, Sun]     [India, Sun]           [Earth]
# 18           NaN          [India]          [India]                []
