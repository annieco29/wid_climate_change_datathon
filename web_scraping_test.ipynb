# %% [markdown]
# ## HTML Beautiful Soup Attempt

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the CNN page you want to scrape
url = "https://edition.cnn.com/world/cnn-climate"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using Beautiful Soup
    soup = BeautifulSoup(response.text, "html.parser")

    # Find and extract article titles and dates
    articles = soup.find_all("div", class_="card")
    
    # Initialize lists to store titles and dates
    article_titles = []
    article_dates = []

    # Loop through the articles and extract titles and dates
    for article in articles:
        title = article.find("h3", class_="card__headline")
        date = article.find("span", class_="card__timestamp")
        
        if title and date:
            article_titles.append(title.text.strip())
            article_dates.append(date.text.strip())

    # Print the extracted titles and dates
    for i in range(len(article_titles)):
        print(f"Title: {article_titles[i]}")
        print(f"Date: {article_dates[i]}")
        print()

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

# %%
article_titles
# Out:
# []

# %%
article_dates
# Out:
# []

# %%
? soup.find_all
# Out:
# Signature:
#  soup.find_all(
#     name=None,
#     attrs={},
#     recursive=True,
#     string=None,
#     limit=None,
#     **kwargs,
# )
# Docstring:
# Look in the children of this PageElement and find all
# PageElements that match the given criteria.
#
# All find_* methods take a common set of arguments. See the online
# documentation for detailed explanations.
#
# :param name: A filter on tag name.
# :param attrs: A dictionary of filters on attribute values.
# :param recursive: If this is True, find_all() will perform a
#     recursive search of this PageElement's children. Otherwise,
#     only the direct children will be considered.
# :param limit: Stop looking after finding this many results.
# :kwargs: A dictionary of filters on attribute values.
# :return: A ResultSet of PageElements.
# :rtype: bs4.element.ResultSet
# File:      ~/anaconda3/envs/wid_datathon_2023/lib/python3.9/site-packages/bs4/element.py
# Type:      method

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the CNN page you want to scrape
url = "https://edition.cnn.com/world/cnn-climate"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using Beautiful Soup
    soup = BeautifulSoup(response.text, "html.parser")

    # Find and extract article titles and dates
    articles = soup.find_all("div", class_="card")

    # Initialize lists to store titles and dates
    article_titles = []
    article_dates = []

    # Loop through the articles and extract titles and dates
    for article in articles:
        print(article)
        title = article.find("div", attrs= {"class":"container__item container__item--type-section"})
        print(title)
        date = article.find("time", class_="card__timestamp")
        
        if title and date:
            article_titles.append(title.text.strip())
            article_dates.append(date["datetime"])

    # Print the extracted titles and dates
    for i in range(len(article_titles)):
        print(f"Title: {article_titles[i]}")
        print(f"Date: {article_dates[i]}")
        print()

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# <div class="card container__item container__item--type-section container_lead-plus-headlines-with-images__item container_lead-plus-headlines-with-images__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/videos/world/2022/04/21/zimbabwe-fishing-climate-change-as-equals-lon-orig.cnn" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000i68nztsslz64p_fill_1@published" data-video-duration="04:37">
# <a class="container__link container_lead-plus-headlines-with-images__link" data-link-type="video" href="/videos/world/2022/04/21/zimbabwe-fishing-climate-change-as-equals-lon-orig.cnn">
# <div class="container__item-media-wrapper container_lead-plus-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_lead-plus-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="Zimbabwe fishing as equals thumbnail 1" data-observe-resizes="" data-original-height="1080" data-original-ratio="0.5625" data-original-width="1920" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000i68nztsslz64p_fill_1@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/220421144738-zimbabwe-fishing-as-equals-thumbnail-1.jpg?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="438" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/220421144738-zimbabwe-fishing-as-equals-thumbnail-1.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="438" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/220421144738-zimbabwe-fishing-as-equals-thumbnail-1.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="270" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/220421144738-zimbabwe-fishing-as-equals-thumbnail-1.jpg?c=16x9&amp;q=h_270,w_480,c_fill" width="480"/><img alt="Zimbabwe fishing as equals thumbnail 1" class="image__dam-img image__dam-img--loading" height="1080" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/220421144738-zimbabwe-fishing-as-equals-thumbnail-1.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="1920"/></picture>
# </div>
# <div class="image__metadata">
# <figcaption class="image__credit">Zinyange Auntony</figcaption>
# </div>
# </div>
# <div class="card__label card__label--type-video">
# <span class="card__label-icon"></span>
# <span class="card__label-bull-span">
# <span class="card__label-indicator">•</span>Video</span>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_lead-plus-headlines-with-images__link" data-link-type="video" href="/videos/world/2022/04/21/zimbabwe-fishing-climate-change-as-equals-lon-orig.cnn">
# <div class="container__text container_lead-plus-headlines-with-images__text">
# <div class="container__headline container_lead-plus-headlines-with-images__headline">
# <span data-editable="headline">She started fishing for a better life. Climate change is putting it all at risk</span>
# </div>
# </div>
# </a>
# </div>
# None
# <div class="card container__item container__item--type-section container_lead-plus-headlines-with-images__item container_lead-plus-headlines-with-images__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/2023/09/27/europe/portugal-climate-lawsuit-human-rights-court-intl/index.html" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000i68nztsslz64p_fill_2@published" data-word-count="1161">
# <a class="container__link container_lead-plus-headlines-with-images__link" data-link-type="article" href="/2023/09/27/europe/portugal-climate-lawsuit-human-rights-court-intl/index.html">
# <div class="container__item-media-wrapper container_lead-plus-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_lead-plus-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="02 leiria portugal wildfires FILE 2017" data-observe-resizes="" data-original-height="2000" data-original-ratio="0.6666666666666666" data-original-width="3000" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000i68nztsslz64p_fill_2@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230926114050-02-leiria-portugal-wildfires-file-2017.jpg?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="438" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230926114050-02-leiria-portugal-wildfires-file-2017.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="438" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230926114050-02-leiria-portugal-wildfires-file-2017.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="270" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230926114050-02-leiria-portugal-wildfires-file-2017.jpg?c=16x9&amp;q=h_270,w_480,c_fill" width="480"/><img alt="LEIRIA, PORTUGAL - JUNE 18:  A burned car stand next to burned houses after a wildfire took dozens of lives on June 18, 2017 near Castanheira de Pera, in Leiria district, Portugal. On Saturday night, a forest fire became uncontrollable in the Leiria district, killing at least 62 people and leaving many injured. Some of the victims died inside their cars as they tried to flee the area.  (Photo by Pablo Blazquez Dominguez/Getty Images)" class="image__dam-img image__dam-img--loading" height="2000" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/230926114050-02-leiria-portugal-wildfires-file-2017.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="3000"/></picture>
# </div>
# <div class="image__metadata">
# <figcaption class="image__credit">Pablo Blazquez Dominguez/Getty Images</figcaption>
# </div>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_lead-plus-headlines-with-images__link" data-link-type="article" href="/2023/09/27/europe/portugal-climate-lawsuit-human-rights-court-intl/index.html">
# <div class="container__text container_lead-plus-headlines-with-images__text">
# <div class="container__headline container_lead-plus-headlines-with-images__headline">
# <span data-editable="headline">‘Truly a David and Goliath case’: Six young people take 32 countries to court in unprecedented case</span>
# </div>
# </div>
# </a>
# </div>
# None
# <div class="card container__item container__item--type-section container_lead-plus-headlines-with-images__item container_lead-plus-headlines-with-images__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/2023/09/27/energy/rosebank-oil-gas-field-britain-climate-intl/index.html" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000i68nztsslz64p_fill_3@published" data-word-count="621">
# <a class="container__link container_lead-plus-headlines-with-images__link" data-link-type="article" href="/2023/09/27/energy/rosebank-oil-gas-field-britain-climate-intl/index.html">
# <div class="container__item-media-wrapper container_lead-plus-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_lead-plus-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="01 north sea oil rig 021323 FILE RESTRICTED" data-observe-resizes="" data-original-height="1333" data-original-ratio="0.6665" data-original-width="2000" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000i68nztsslz64p_fill_3@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230927031258-01-north-sea-oil-rig-021323-file-restricted.jpg?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="438" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230927031258-01-north-sea-oil-rig-021323-file-restricted.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="438" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230927031258-01-north-sea-oil-rig-021323-file-restricted.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="270" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230927031258-01-north-sea-oil-rig-021323-file-restricted.jpg?c=16x9&amp;q=h_270,w_480,c_fill" width="480"/><img alt="The Equinor ASA offshore oil drilling platform on Johan Sverdrup oil field in the North Sea, Norway, on Monday, Feb. 13, 2023. Equinor, Norway's biggest oil and gas producer, said the second phase of its giant Johan Sverdrup field in the North Sea is now on stream. Photographer: Carina Johansen/Bloomberg" class="image__dam-img image__dam-img--loading" height="1333" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/230927031258-01-north-sea-oil-rig-021323-file-restricted.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="2000"/></picture>
# </div>
# <div class="image__metadata">
# <figcaption class="image__credit">Carina Johansen/Bloomberg/Getty Images/FILE</figcaption>
# </div>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_lead-plus-headlines-with-images__link" data-link-type="article" href="/2023/09/27/energy/rosebank-oil-gas-field-britain-climate-intl/index.html">
# <div class="container__text container_lead-plus-headlines-with-images__text">
# <div class="container__headline container_lead-plus-headlines-with-images__headline">
# <span data-editable="headline">Britain approves huge, controversial oil and gas field in the North Sea</span>
# </div>
# </div>
# </a>
# </div>
# None
# <div class="card container__item container__item--type-section container
onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/230925123816-global-fossil-fuel-co2-emissions-restricted.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="2000"/></picture>
# </div>
# <div class="image__metadata">
# <figcaption class="image__credit">Kena Betancur/VIEWpress/Getty Images</figcaption>
# </div>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_lead-plus-headlines-with-images__link" data-link-type="article" href="/2023/09/26/energy/fossil-fuels-demand-peak-climate-action-iea/index.html">
# <div class="container__text container_lead-plus-headlines-with-images__text">
# <div class="container__headline container_lead-plus-headlines-with-images__headline">
# <span data-editable="headline">‘Not nearly enough.’ IEA says fossil fuel demand will peak soon but urges faster action</span>
# </div>
# </div>
# </a>
# </div>
# None
# <div class="card container__item container__item--type-section container_lead-plus-headlines-with-images__item container_lead-plus-headlines-with-images__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/videos/us/2023/09/26/exp-new-orleans-saltwater-mississippi-river-weir-sot-092602aseg2-cnni-us.cnn" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000i68nztsslz64p_fill_9@published" data-video-duration="01:51">
# <a class="container__link container_lead-plus-headlines-with-images__link" data-link-type="video" href="/videos/us/2023/09/26/exp-new-orleans-saltwater-mississippi-river-weir-sot-092602aseg2-cnni-us.cnn">
# <div class="container__item-media-wrapper container_lead-plus-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_lead-plus-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="exp New Orleans Saltwater Mississippi River Weir SOT 092602ASEG2 CNNi US_00002001" data-observe-resizes="" data-original-height="1080" data-original-ratio="0.5625" data-original-width="1920" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000i68nztsslz64p_fill_9@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230926044025-exp-new-orleans-saltwater-mississippi-river-weir-sot-092602aseg2-cnni-us-00002001.png?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="438" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230926044025-exp-new-orleans-saltwater-mississippi-river-weir-sot-092602aseg2-cnni-us-00002001.png?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="438" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230926044025-exp-new-orleans-saltwater-mississippi-river-weir-sot-092602aseg2-cnni-us-00002001.png?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="270" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230926044025-exp-new-orleans-saltwater-mississippi-river-weir-sot-092602aseg2-cnni-us-00002001.png?c=16x9&amp;q=h_270,w_480,c_fill" width="480"/><img alt="exp New Orleans Saltwater Mississippi River Weir SOT 092602ASEG2 CNNi US_00002001.png" class="image__dam-img image__dam-img--loading" height="1080" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/230926044025-exp-new-orleans-saltwater-mississippi-river-weir-sot-092602aseg2-cnni-us-00002001.png?c=16x9&amp;q=h_438,w_780,c_fill" width="1920"/></picture>
# </div>
# <div class="image__metadata"></div>
# </div>
# <div class="card__label card__label--type-video">
# <span class="card__label-icon"></span>
# <span class="card__label-bull-span">
# <span class="card__label-indicator">•</span>Video</span>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_lead-plus-headlines-with-images__link" data-link-type="video" href="/videos/us/2023/09/26/exp-new-orleans-saltwater-mississippi-river-weir-sot-092602aseg2-cnni-us.cnn">
# <div class="container__text container_lead-plus-headlines-with-images__text">
# <div class="container__headline container_lead-plus-headlines-with-images__headline">
# <span data-editable="headline">Saltwater creeping up Mississippi River threatens New Orleans water supply</span>
# </div>
# </div>
# </a>
# </div>
# None
# <div class="card container__item container__item--type-section container_lead-plus-headlines-with-images__item container_lead-plus-headlines-with-images__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/videos/tv/2023/09/25/amanpour-annalena-baerbock-ukraine-unga.cnn" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000i68nztsslz64p_fill_10@published" data-video-duration="16:44">
# <a class="container__link container_lead-plus-headlines-with-images__link" data-link-type="video" href="/videos/tv/2023/09/25/amanpour-annalena-baerbock-ukraine-unga.cnn">
# <div class="container__item-media-wrapper container_lead-plus-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_lead-plus-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="Amanpour Baerbock" data-observe-resizes="" data-original-height="1080" data-original-ratio="0.5625" data-original-width="1920" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000i68nztsslz64p_fill_10@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230925185227-amanpour-baerbock.jpg?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="438" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230925185227-amanpour-baerbock.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="438" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230925185227-amanpour-baerbock.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="780"/><source height="270" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230925185227-amanpour-baerbock.jpg?c=16x9&amp;q=h_270,w_480,c_fill" width="480"/><img alt="Amanpour Baerbock" class="image__dam-img image__dam-img--loading" height="1080" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/230925185227-amanpour-baerbock.jpg?c=16x9&amp;q=h_438,w_780,c_fill" width="1920"/></picture>
# </div>
# <div class="image__metadata"></div>
# </div>
# <div class="card__label card__label--type-video">
# <span class="card__label-icon"></span>
# <span class="card__label-bull-span">
# <span class="card__label-indicator">•</span>Video</span>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_lead-plus-headlines-with-images__link" data-link-type="video" href="/videos/tv/2023/09/25/amanpour-annalena-baerbock-ukraine-unga.cnn">
# <div class="container__text container_lead-plus-headlines-with-images__text">
# <div class="container__headline container_lead-plus-headlines-with-images__headline">
# <span data-editable="headline">If Russia wins, ‘this will be the end of peaceful cooperation,’ says German Foreign Minister</span>
# </div>
# </div>
# </a>
# </div>
# None
# <div class="card container__item container__item--type-section container_list-headlines-with-images__item container_list-headlines-with-images__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/2023/09/16/world/global-rain-flooding-climate-crisis-intl-hnk/index.html" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000k68nz9fkdc373_fill_1@published" data-word-count="1408">
# <a class="container__link container_list-headlines-with-images__link" data-link-type="article" href="/2023/09/16/world/global-rain-flooding-climate-crisis-intl-hnk/index.html">
# <div class="container__item-media-wrapper container_list-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_list-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="08 libya flooding 091223 Derna" data-observe-resizes="" data-original-height="900" data-original-ratio="0.5625" data-original-width="1600" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000k68nz9fkdc373_fill_1@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230913105006-08-libya-flooding-091223-derna.jpg?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="144" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230913105006-08-libya-flooding-091223-derna.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230913105006-08-libya-flooding-091223-derna.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230913105006-08-libya-flooding-091223-derna.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><img alt="A general view of the city of Derna is seen on Tuesday, Sept. 12., 2023. Mediterranean storm Daniel caused devastating floods in Libya that broke dams and swept away entire neighborhoods in multiple coastal towns, the destruction appeared greatest in Derna city. (AP Photo/Jamal Alkomaty)" class="image__dam-img image__dam-img--loading" height="900" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/230913105006-08-libya-flooding-091223-derna.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="1600"/></picture>
# </div>
# <div class="image__metadata">
# <figcaption class="image__credit">Jamal Alkomaty/AP</figcaption>
# </div>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_list-headlines-with-images__link" data-link-type="article" href="/2023/09/16/world/global-rain-flooding-climate-crisis-intl-hnk/index.html">
# <div class="container__text container_list-headlines-with-images__text">
# <div class="container__headline container_list-headlines-with-images__headline">
# <span data-editable="headline">Ten countries and territories saw severe flooding in just 12 days. Is this the future of climate change?</span>
# </div>
# <div class="container__date container_list-headlines-with-images__date inline-placeholder">
#                     Sep 18, 2023
#                 </div>
# </div>
# </a>
# </div>
# None
# <div class="card container__item container__item--type-section container_list-headlines-with-images__item container_list-headlines-with-images__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/2023/09/14/middleeast/lethal-factors-leading-to-libya-floods-intl/index.html" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000k68nz9fkdc373_fill_2@published" data-word-count="1044">
# <a class="container__link container_list-headlines-with-images__link" data-link-type="article" href="/2023/09/14/middleeast/lethal-factors-leading-to-libya-floods-intl/index.html">
# <div class="container__item-media-wrapper container_list-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_list-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="factors in Libya flooding" data-observe-resizes="" data-original-height="1096" data-original-ratio="0.548" data-original-width="2000" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000k68nz9fkdc373_fill_2@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230914132857-factors-in-libya-flooding.jpg?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="144" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230914132857-factors-in-libya-flooding.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230914132857-factors-in-libya-flooding.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230914132857-factors-in-libya-flooding.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><img alt="A satellite image shows the town of Derna in the aftermath of the floods in eastern Libya on Wednesday." class="image__dam-img image__dam-img--loading" height="1096" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/230914132857-factors-in-libya-flooding.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="2000"/></picture>
# </div>
# <div class="image__metadata">
# <figcaption class="image__credit">Maxar Technologies/Reuters</figcaption>
# </div>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_list-headlines-with-images__link" data-link-type="article" href="/2023/09/14/middleeast/lethal-factors-leading-to-libya-floods-intl/index.html">
# <div class="container__text container_list-headlines-with-images__text">
# <div class="container__headline container_list-headlines-with-images__headline">
# <span data-editable="headline">Aging dams and missed warnings: A lethal mix of factors caused Africa’s deadliest flood disaster</span>
# </div>
# <div class="container__date container_list-headlines-with-images__date inline-placeholder">
#                     Sep 15, 2023
#                 </div>
# </div>
# </a>
# </div>
# None
# <div class="card container__item container__item--type-section container_list-headlines-with-images__item container_list-headlines-with-images__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/2023/09/13/world/planetary-boundaries-humanity-climate/index.html" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000k68nz9fkdc373_fill_3@published" data-word-count="871">
# <a class="container__link container_list-headlines-with-images__link" data-link-type="article" href="/2023/09/13/world/planetary-boundaries-humanity-climate/index.html">
# <div class="container__item-media-wrapper container_list-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_list-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="01 Lake Mead 012723" data-observe-resizes="" data-original-height="1600" data-original-ratio="0.5625879043600562" data-original-width="2844" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000k68nz9fkdc373_fill_3@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230913100747-01-lake-mead-012723.jpg?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="144" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230913100747-01-lake-mead-012723.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230913100747-01-lake-mead-012723.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230913100747-01-lake-mead-012723.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><img alt="Cracked earth is visible in an area once under the water of Lake Mead at the Lake Mead National Recreation Area on Jan. 27, 2023, near Boulder City, Nevada." class="image__dam-img image__dam-img--loading" height="1600" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/230913100747-01-lake-mead-012723.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="2844"/></picture>
# </div>
# <div class="image__metadata">
# <figcaption class="image__credit">John Locher/AP</figcaption>
# </div>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_list-headlines-with-images__link" data-link-type="article" href="/2023/09/13/world/planetary-boundaries-humanity-climate/index.html">
# <div class="container__text container_list-headlines-with-images__text">
# <div class="container__headline container_list-headlines-with-images__headline">
# <span data-editable="headline">Conditions on Earth may be moving outside the ‘safe operating space’ for humanity, according to dozens of scientists</span>
# </div>
# <div class="container__date container_list-headlines-with-images__date inline-placeholder">
#                     Sep 13, 2023
#                 </div>
# </div>
# </a>
# </div>
# None
# <div class="card container__item container__item--type-section container_list-headlines-with-images__item container_list-headlines-with-images__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/style/article/vladimir-jurowski-protesters-climate-scli-intl/index.html" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000k68nz9fkdc373_fill_4@published" data-word-count="582">
# <a class="container__link container_list-headlines-with-images__link" data-link-type="article" href="/style/article/vladimir-jurowski-protesters-climate-scli-intl/index.html">
# <div class="container__item-media-wrapper container_list-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_list-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="Vladimir Jurowski 050522" data-observe-resizes="" data-original-height="1333" data-original-ratio="0.6665" data-original-width="2000" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000k68nz9fkdc373_fill_4@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230911122721-vladimir-jurowski-050522.jpg?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# ...
# <div class="container__headline container_list-headlines-with-images__headline">
# <span data-editable="headline">Renowned conductor allows climate activists to address crowd at Swiss music festival</span>
# </div>
# <div class="container__date container_list-headlines-with-images__date inline-placeholder">
#                     Sep 11, 2023
#                 </div>
# </div>
# </a>
# </div>
# None
# <div class="card container__item container__item--type-section container_list-headlines-with-images__item container_list-headlines-with-images__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/videos/business/2023/09/22/exp-sustainable-aviation-fuel-delta-airlines-amelia-deluca-092203pseg2-business-cnni.cnn" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000l68nznpdjtp0w_fill_1@published" data-video-duration="02:58">
# <a class="container__link container_list-headlines-with-images__link" data-link-type="video" href="/videos/business/2023/09/22/exp-sustainable-aviation-fuel-delta-airlines-amelia-deluca-092203pseg2-business-cnni.cnn">
# <div class="container__item-media-wrapper container_list-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_list-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="exp sustainable aviation fuel Delta Airlines Amelia DeLuca 092203PSEG2 business cnni_00002001" data-observe-resizes="" data-original-height="1080" data-original-ratio="0.5625" data-original-width="1920" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000l68nznpdjtp0w_fill_1@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230922171618-exp-sustainable-aviation-fuel-delta-airlines-amelia-deluca-092203pseg2-business-cnni-00002001.png?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="144" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230922171618-exp-sustainable-aviation-fuel-delta-airlines-amelia-deluca-092203pseg2-business-cnni-00002001.png?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230922171618-exp-sustainable-aviation-fuel-delta-airlines-amelia-deluca-092203pseg2-business-cnni-00002001.png?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230922171618-exp-sustainable-aviation-fuel-delta-airlines-amelia-deluca-092203pseg2-business-cnni-00002001.png?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><img alt="exp sustainable aviation fuel Delta Airlines Amelia DeLuca 092203PSEG2 business cnni_00002001.png" class="image__dam-img image__dam-img--loading" height="1080" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/
cnn" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000l68nznpdjtp0w_fill_3@published" data-video-duration="18:08">
# <a class="container__link container_list-headlines-with-images__link" data-link-type="video" href="/videos/world/2023/09/21/as-equals-un-climate-action-selwin-hart-intv-rachel-ramirez.cnn">
# <div class="container__item-media-wrapper container_list-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_list-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="slewing hart un" data-observe-resizes="" data-original-height="1080" data-original-ratio="0.5625" data-original-width="1920" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000l68nznpdjtp0w_fill_3@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230921123225-slewing-hart-un.jpg?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="144" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230921123225-slewing-hart-un.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230921123225-slewing-hart-un.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230921123225-slewing-hart-un.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><img alt="slewing hart un" class="image__dam-img image__dam-img--loading" height="1080" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/230921123225-slewing-hart-un.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="1920"/></picture>
# </div>
# <div class="image__metadata">
# <figcaption class="image__credit">Kyung Lah/CNN</figcaption>
# </div>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_list-headlines-with-images__link" data-link-type="video" href="/videos/world/2023/09/21/as-equals-un-climate-action-selwin-hart-intv-rachel-ramirez.cnn">
# <div class="container__text container_list-headlines-with-images__text">
# <div class="container__headline container_list-headlines-with-images__headline">
# <svg class="icon-sig-video" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 3.333c-4.779 0-8.667 3.888-8.667 8.667S7.221 20.667 12 20.667s8.667-3.888 8.667-8.667S16.779 3.333 12 3.333M12 22C6.486 22 2 17.514 2 12S6.486 2 12 2s10 4.486 10 10-4.486 10-10 10m-1.064-6.793l4.61-2.74a.715.715 0 00-.003-1.23l-4.61-2.712a.714.714 0 00-1.076.616v5.452c0 .554.603.897 1.08.614"></path></svg>
# <span data-editable="headline">‘We need to be serious in stepping up support to protect (women and girls’) lives and livelihoods’, says UN Special Adviser on Climate Action</span>
# </div>
# <div class="container__date container_list-headlines-with-images__date inline-placeholder">
#                     Sep 21, 2023
#                 </div>
# </div>
# </a>
# </div>
# None
# <div class="card container__item container__item--type-section container_list-headlines-with-images__item container_list-headlines-with-images__item--type-section" data-component-name="card" data-created-updated-by="true" data-open-link="/videos/tv/2023/09/21/amanpour-nuland-ukraine-unga.cnn" data-unselectable="true" data-uri="cms.cnn.com/_components/card/instances/clezurg57000l68nznpdjtp0w_fill_4@published" data-video-duration="12:11">
# <a class="container__link container_list-headlines-with-images__link" data-link-type="video" href="/videos/tv/2023/09/21/amanpour-nuland-ukraine-unga.cnn">
# <div class="container__item-media-wrapper container_list-headlines-with-images__item-media-wrapper" data-breakpoints='{"card--media-large": 596}'>
# <div class="container__item-media container_list-headlines-with-images__item-media">
# <div class="image image__hide-placeholder" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300}' data-component-name="image" data-image-variation="image" data-name="Amanpour Nuland" data-observe-resizes="" data-original-height="1080" data-original-ratio="0.5625" data-original-width="1920" data-unselectable="true" data-uri="cms.cnn.com/_components/image/instances/card_clezurg57000l68nznpdjtp0w_fill_4@published" data-url="https://media.cnn.com/api/v1/images/stellar/prod/230921134621-amanpour-nuland.jpg?c=original">
# <div class="image__container" data-breakpoints='{"image--eq-extra-small": 115, "image--eq-small": 300, "image--show-credits": 596}' data-image-variation="image">
# <picture class="image__picture"><source height="144" media="(min-width: 1280px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230921134621-amanpour-nuland.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(min-width: 960px)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230921134621-amanpour-nuland.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><source height="144" media="(-webkit-min-device-pixel-ratio: 2)" srcset="https://media.cnn.com/api/v1/images/stellar/prod/230921134621-amanpour-nuland.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="256"/><img alt="Amanpour Nuland" class="image__dam-img image__dam-img--loading" height="1080" onerror="imageLoadError(this)" onload="this.classList.remove('image__dam-img--loading')" src="https://media.cnn.com/api/v1/images/stellar/prod/230921134621-amanpour-nuland.jpg?c=16x9&amp;q=h_144,w_256,c_fill" width="1920"/></picture>
# </div>
# <div class="image__metadata"></div>
# </div>
# </div>
# </div>
# </a>
# <a class="container__link container_list-headlines-with-images__link" data-link-type="video" href="/videos/tv/2023/09/21/amanpour-nuland-ukraine-unga.cnn">
# <div class="container__text container_list-headlines-with-images__text">
# <div class="container__headline container_list-headlines-with-images__headline">
# <svg class="icon-sig-video" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 3.333c-4.779 0-8.667 3.888-8.667 8.667S7.221 20.667 12 20.667s8.667-3.888 8.667-8.667S16.779 3.333 12 3.333M12 22C6.486 22 2 17.514 2 12S6.486 2 12 2s10 4.486 10 10-4.486 10-10 10m-1.064-6.793l4.61-2.74a.715.715 0 00-.003-1.23l-4.61-2.712a.714.714 0 00-1.076.616v5.452c0 .554.603.897 1.08.614"></path></svg>
# <span data-editable="headline">Senior U.S. diplomat: ‘We need to address all these global problems together’</span>
# </div>
# <div class="container__date container_list-headlines-with-images__date inline-placeholder">
#                     Sep 21, 2023
#                 </div>
# </div>
# </a>
# </div>
# None

# %% [markdown]
# ## RSS Beautiful Soup Attempt

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# install lxml to parse xml code in RSS sites
# RSS sites are in xml format and make it easy to parse the articl title, description, link and date (downside is they don't contain full article)
# list of CNN's RSS sites: https://edition.cnn.com/services/rss/
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /Users/anniecondon/anaconda3/envs/wid_datathon_2023/lib/python3.9/site-packages (4.9.3)

# %%
# Function to get the various attributes of the article
def getArticles(articles):
    all_articles = []
    for article in articles:
        article_title = article.find('title').text
        article_link = getattr(article.find('link'), 'text', None)
        article_desc = getattr(article.find('description'), 'text', None)
        article_published = getattr(article.find('pubDate'), 'text', None)
        all_articles.append({
            'title':article_title,
            'link':article_link,
            'description':article_desc,
            'published':article_published
        })
    return all_articles
    
# Function to invoke CNN Scrapper
def cnn_news_scrapper(URL):
    try:
        r = requests.get(URL)
        soupContent = BeautifulSoup(r.content,'xml')
        print('Job Succeeded returning Status Code: ', r.status_code)
        items = soupContent.findAll('item')
        print('Total News Content')
        print(len(items))
        print(items)
        return getArticles(soupContent.findAll('item'))
    except Exception as e:
        print('Scraping failed due to the below exception')
        print(e)

# %%
print('Starting scraping')
data = cnn_news_scrapper('http://rss.cnn.com/rss/money_news_international.rss')
print('Finished scraping')
# Out:
# Starting scraping
# Job Succeeded returning Status Code:  200
# Total News Content
# 20
# [<item>
# <title>Mexico ready to retaliate by hurting US farmers</title>
# <link>http://money.cnn.com/2017/02/13/news/economy/mexico-trump-us-corn/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/13/news/economy/mexico-trump-us-corn/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/170213111654-us-corn-field-nafta-120x90.jpg" width="120"/>
# <description>Mexican Senator Armando Rios Piter told CNN that he plans to introduce a bill this week that would stop Mexican purchases of American corn. </description>
# <pubDate>Mon, 13 Feb 2017 12:37:06 EST</pubDate>
# </item>, <item>
# <title>Will the next iPhone charge wirelessly? </title>
# <link>http://money.cnn.com/2017/02/13/technology/apple-wireless-charging/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/13/technology/apple-wireless-charging/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/170203124414-apple-iphone-120x90.jpg" width="120"/>
# <description>The days of plugging in an iPhone to charge won't last forever.</description>
# <pubDate>Mon, 13 Feb 2017 14:42:14 EST</pubDate>
# </item>, <item>
# <title>How 'America First' could turn into to 'India First'</title>
# <link>http://money.cnn.com/2017/02/13/technology/india-h1b-visa-trump-nandan-nilekani/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/13/technology/india-h1b-visa-trump-nandan-nilekani/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/170213235903-nandan-nilekani-120x90.jpg" width="120"/>
# <description>Nandan Nilekani, co-founder of one of India's biggest outsourcing companies, says an H-1B visa crackdown would ultimately hurt the U.S. </description>
# <pubDate>Mon, 13 Feb 2017 14:20:08 EST</pubDate>
# </item>, <item>
# <title>Swiss voters reject corporate tax overhaul</title>
# <link>http://money.cnn.com/2017/02/13/pf/taxes/switzerland-tax-referendum-vote/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/13/pf/taxes/switzerland-tax-referendum-vote/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/170213104024-switzerland-referendum-tax-120x90.jpg" width="120"/>
# <description>Read full story for latest details.</description>
# <pubDate>Mon, 13 Feb 2017 10:45:35 EST</pubDate>
# </item>, <item>
# <title>Stocks hit record again. Is Trump the reason?</title>
# <link>http://money.cnn.com/2017/02/13/investing/stocks-all-time-highs-donald-trump-janet-yellen-fed/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/13/investing/stocks-all-time-highs-donald-trump-janet-yellen-fed/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/160921153004-janet-yellen-donald-trump-120x90.jpg" width="120"/>
# <description>The market is at all-time highs and many say Trump is the reason. But stocks were rallying when investors thought Hillary Clinton would win. Janet Yellen and the Fed may deserve more of the credit for the market's move.</description>
# <pubDate>Mon, 13 Feb 2017 12:35:07 EST</pubDate>
# </item>, <item>
# <title>Apple stock nears record high</title>
# <link>http://money.cnn.com/2017/02/13/technology/apple-stock-record/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/13/technology/apple-stock-record/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/160727103035-apple-stocks-up-120x90.jpg" width="120"/>
# <description>Apple stock is less than $1 away from its all-time high amid renewed optimism for the iPhone. </description>
# <pubDate>Mon, 13 Feb 2017 12:24:58 EST</pubDate>
# </item>, <item>
# <title>America's NAFTA nemesis: Canada, not Mexico</title>
# <link>http://money.cnn.com/2017/02/13/news/economy/nafta-canada-trudeau-trump-mexico/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/13/news/economy/nafta-canada-trudeau-trump-mexico/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/170124112944-trudeau-trump-pena-nieto-120x90.jpg" width="120"/>
# <description>President-elect Donald Trump focuses his criticism of NAFTA on Mexico. But Canada and America have a rocky trade history too.</description>
# <pubDate>Mon, 13 Feb 2017 11:59:43 EST</pubDate>
# </item>, <item>
# <title>Verizon's plan: Consumers win, investors lose</title>
# <link>http://money.cnn.com/2017/02/13/investing/verizon-stock-unlimited-data-plan/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/13/investing/verizon-stock-unlimited-data-plan/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/160129141906-verizon-logo-store-120x90.jpg" width="120"/>
# <description>Verizon has decided to bring back unlimited data plans. But while that's great for its subscribers, it's awful news for investors. It's another sign of how brutally competitive the telecom business is. And it's hurting Verizon's stock.</description>
# <pubDate>Mon, 13 Feb 2017 11:32:13 EST</pubDate>
# </item>, <item>
# <title>Oil prices have doubled in a year. Here's why</title>
# <link>http://money.cnn.com/2017/02/13/investing/oil-prices-opec-deal/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/13/investing/oil-prices-opec-deal/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/161107161529-election2016-markets-oil-up-120x90.jpg" width="120"/>
# <description>The price of crude oil has more than doubled over the past year after bottoming out at $26 per barrel in February 2016. </description>
# <pubDate>Mon, 13 Feb 2017 09:39:58 EST</pubDate>
# </item>, <item>
# <title>Tesla will sell electric cars in the Middle East</title>
# <link>http://money.cnn.com/2017/02/13/investing/tesla-uae-elon-musk/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/13/investing/tesla-uae-elon-musk/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/160902082845-elon-musk-debt-120x90.jpg" width="120"/>
# <description>The automaker announced Monday that its first official venture in the oil-rich Middle East will be in the United Arab Emirates. </description>
# <pubDate>Mon, 13 Feb 2017 11:18:47 EST</pubDate>
# </item>, <item>
# <title>Indian rival slams Uber's business model</title>
# <link>http://money.cnn.com/2017/02/13/technology/uber-ola-india-pranay-jivrajka/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/13/technology/uber-ola-india-pranay-jivrajka/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/160908162720-uber-taxi-phone-logo-120x90.jpg" width="120"/>
# <description>Uber's top rival in India has some unsolicited advice for the U.S. startup: Go local.</description>
# <pubDate>Mon, 13 Feb 2017 08:48:42 EST</pubDate>
# </item>, <item>
# <title>Cook calls for campaign against fake news</title>
# <link>http://money.cnn.com/2017/02/11/media/fake-news-apple-ceo-tim-cook/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02
index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/10/news/economy/visa-ban-rural-doctor-shortage/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/170210105854-dr-nofal-patient-120x90.jpg" width="120"/>
# <description>Read full story for latest details.</description>
# <pubDate>Fri, 10 Feb 2017 20:02:55 EST</pubDate>
# </item>, <item>
# <title>Trump isn't killing the bull market. Here's why</title>
# <link>http://money.cnn.com/2017/02/10/investing/stocks-united-states-trump-europe-china-japan/index.html?section=money_news_international</link>
# <guid>http://money.cnn.com/2017/02/10/investing/stocks-united-states-trump-europe-china-japan/index.html?section=money_news_international</guid>
# <media:thumbnail height="90" url="http://i2.cdn.turner.com/money/dam/assets/170208121205-trump-bull-120x90.jpg" width="120"/>
# <description>Read full story for latest details.</description>
# <pubDate>Fri, 10 Feb 2017 11:55:17 EST</pubDate>
# </item>]
# Finished scraping

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#                                                title  \
# 0    Mexico ready to retaliate by hurting US farmers
# 1           Will the next iPhone charge wirelessly?
# 2  How 'America First' could turn into to 'India ...
# 3         Swiss voters reject corporate tax overhaul
# 4      Stocks hit record again. Is Trump the reason?
#
#                                                 link  \
# 0  http://money.cnn.com/2017/02/13/news/economy/m...
# 1  http://money.cnn.com/2017/02/13/technology/app...
# 2  http://money.cnn.com/2017/02/13/technology/ind...
# 3  http://money.cnn.com/2017/02/13/pf/taxes/switz...
# 4  http://money.cnn.com/2017/02/13/investing/stoc...
#
#                                          description  \
# 0  Mexican Senator Armando Rios Piter told CNN th...
# 1  The days of plugging in an iPhone to charge wo...
# 2  Nandan Nilekani, co-founder of one of India's ...
# 3                Read full story for latest details.
# 4  The market is at all-time highs and many say T...
#
#                        published
# 0  Mon, 13 Feb 2017 12:37:06 EST
# 1  Mon, 13 Feb 2017 14:42:14 EST
# 2  Mon, 13 Feb 2017 14:20:08 EST
# 3  Mon, 13 Feb 2017 10:45:35 EST
# 4  Mon, 13 Feb 2017 12:35:07 EST

# %%
df.shape
# Out:
# (20, 4)

# %%
df.head(30)
# Out:
#                                                 title  \
# 0     Mexico ready to retaliate by hurting US farmers
# 1            Will the next iPhone charge wirelessly?
# 2   How 'America First' could turn into to 'India ...
# 3          Swiss voters reject corporate tax overhaul
# 4       Stocks hit record again. Is Trump the reason?
# 5                       Apple stock nears record high
# 6         America's NAFTA nemesis: Canada, not Mexico
# 7       Verizon's plan: Consumers win, investors lose
# 8       Oil prices have doubled in a year. Here's why
# 9    Tesla will sell electric cars in the Middle East
# 10           Indian rival slams Uber's business model
# 11          Cook calls for campaign against fake news
# 12                      Trump brand takes another hit
# 13          Cutting down trash with bamboo packaging
# 14           Nike stars champion 'Equality' in new ad
# 15         'Lego Batman' producer, then Treasury sec?
# 16      Are we heading for another Greek debt crisis?
# 17            Verizon is bringing back unlimited data
# 18   Visa crackdown puts these rural doctors at risk
# 19    Trump isn't killing the bull market. Here's why
#
#                                                  link  \
# 0   http://money.cnn.com/2017/02/13/news/economy/m...
